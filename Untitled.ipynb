# %%
import requests
import requests_oauthlib

# %%
from donthackme import CONSUMER_KEY, CONSUMER_SECRET, TOKEN, TOKEN_SECRET # create api
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-26-ff189d900713> in <module>
# ----> 1 from donthackme import CONSUMER_KEY, CONSUMER_SECRET, TOKEN, TOKEN_SECRET # create api
#
# ModuleNotFoundError: No module named 'donthackme'

# %%
url = 'https://api.twitter.com/1.1/account/verify_credentials.json'

# %%
auth = requests_oauthlib.OAuth1(CONSUMER_KEY, CONSUMER_SECRET, TOKEN, TOKEN_SECRET)
verify_response = requests.get(url, auth)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-55303d85569e> in <module>
#       1 auth = requests_oauthlib.OAuth1(CONSUMER_KEY, CONSUMER_SECRET, TOKEN, TOKEN_SECRET)
# ----> 2 verify_response = requests.get(url, auth)
#
# /usr/local/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# /usr/local/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ...

# %%
verify_response.json()['name']
verify_response.json()['screen_name']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-0d843e9211e5> in <module>
# ----> 1 verify_response.json()['name']
#       2 verify_response.json()['screen_name']
#
# NameError: name 'verify_response' is not defined

# %%
search_url = 'https://api.twitter.com/1.1/search/tweets.json'
params = {'q': 'data science', 'result_type': 'recent'}

# %%
search_response = requests.get(search_url, params=params, auth=auth)

# %%
search_response
# Out:
# <Response [200]>

# %%
search_response.json()
# Out:
# {'statuses': [{'created_at': 'Thu Sep 26 08:00:22 +0000 2019',
#    'id': 1177130780021022721,
#    'id_str': '1177130780021022721',
#    'text': 'RT @ProfPCDoherty: Science is data driven. True conservatives tend to like science because they think evidence is important. Reactionaries…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ProfPCDoherty',
#       'name': 'Prof. Peter Doherty',
#       'id': 602403521,
#       'id_str': '602403521',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 23290453,
#     'id_str': '23290453',
# ...
